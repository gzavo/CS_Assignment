# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("istherecorrelation.csv", sep=';')

year = data.loc[:,"Year"]
wo = data.loc[:,"WO [x1000]"]
nl = data.loc[:,"NL Beer consumption [x1000 hectoliter]"]

wo = wo

plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

fig, ax = plt.subplots()
ax.plot(wo, nl)
