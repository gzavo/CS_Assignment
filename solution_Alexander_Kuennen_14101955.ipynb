# %% [markdown]
# This is the markdown file for the assignment

# %%
#Idea of SIR algorithm
import matplotlib as mlp
import matplotlib.pyplot as plt
import numpy as np
import csv
# %matplotlib notebook

x_values = []
y_values = []
z_values = []
with open('istherecorrelation.csv', newline='') as csvfile:
    spamreader = csv.reader(csvfile, delimiter=';', quotechar='|')
    spamreader.__next__()
    for row in spamreader:
        x_values.append(int(row[0].replace(',','.')))
        y_values.append(float(row[1].replace(',','.')))
        z_values.append(int(row[2].replace(',','.')))


plt.figure()
plt.plot(x_values,y_values,'g*')
plt.xlabel('year')
plt.ylabel('WO') 
plt.ylim(0,max(y_values))
plt.savefig('2d_1_plot.png', dpi=300)

print("Average WO:",np.mean(y_values),"STD WO:",np.std(y_values))

plt.figure()
plt.plot(x_values,z_values,'g*')
plt.xlabel('year')
plt.ylabel('hectoliter beer') 
plt.ylim(0,max(z_values))
plt.savefig('2d_2_plot.png', dpi=300)


print("Average Hectoliter Beer:",np.mean(z_values),"STD Hectoliter Beer:",np.std(z_values))
# Out:
# <img src="data:image/png;base64,..." width="640">
# Average WO: 240.39999999999998 STD WO: 22.432359867628044
# <img src="data:image/png;base64,..." width="640">
# Average Hectoliter Beer: 11579.461538461539 STD Hectoliter Beer: 182.2211738877174

# %% [markdown]
# <img src="2d_1_plot.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# In this plot you can see the developement of the washouts in the years 2006-2018.
# A total increase of 74.2 washouts can be seen.<br />
# Average WO: 240.39999999999998 STD WO: 22.432359867628044

# %% [markdown]
# <img src="2d_2_plot.png" alt="Drawing" style="width: 500px;"/>

# %% [markdown]
# In this plot you can see the developement of the amount of beer in hectoliter in the years 2006-2018.
# A small increase in the amount of beer can be seen.<br />
# Average Hectoliter Beer: 11579.461538461539 STD Hectoliter Beer: 182.2211738877174
