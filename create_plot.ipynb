# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('istherecorrelation.csv', sep=';', na_values='.')

# %%
fig,ax = plt.subplots()
# make a plot
ax.plot(df["Year"], 
        df["NL Beer consumption [x1000 hectoliter]"],
        color="red", 
        marker="o")
# set x-axis label
ax.set_xlabel("year", fontsize = 14)
# set y-axis label
ax.set_ylabel("NL Beer consumption [x1000 hectoliter]",
              color="red",
              fontsize=14)
# Out:
# Text(0, 0.5, 'NL Beer consumption [x1000 hectoliter]')

# %%
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(df["Year"], df["WO [x1000]"],color="blue",marker="o")
ax2.set_ylabel("WO [x1000]",color="blue",fontsize=14)
plt.show()
# save the plot as a file
fig.savefig('beer_consumption.jpg',
            format='jpeg',
            dpi=300,
            bbox_inches='tight')
