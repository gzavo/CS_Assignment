# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import pandas as pd
import seaborn as sns

# %%
import csv

inputfile = pd.read_csv('istherecorrelation.csv', sep=';', decimal=',')

ax = sns.lmplot(x='WO [x1000]', y='NL Beer consumption [x1000 hectoliter]', data=inputfile)
plt.title('Relation between amount of students and beer consumption')

ax.figure.savefig('solution_figure.png',dpi=300)
plt.show()
